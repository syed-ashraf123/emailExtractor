# %%
import pandas as pd
import requests

# %%
df=pd.read_csv("_Alabama.csv")

# %%
for c,i in enumerate(df["website"][0:2]):
    res=requests.get(i)
    print(res.status_code)
    df.at[c,"email"]=res.status_code
# Out:
# 403
# 403

# %%
df
# Out:
#                                                   name  \
# 0    A Reprieve for Women - Long Term Drug Rehab fr...
# 1                             Bradford Health Services
# 2                               Rapha Treatment Center
# 3    A Reprieve for Men - Long-Term Rehab from Brad...
# 4                                 Living Free Recovery
# ..                                                 ...
# 131                      Carolyn E King Rehabilitation
# 132   AltaPointe Health Outpatient - Washington County
# 133                 Vocational Rehabilitation Services
# 134                                            Al-anon
# 135                       Downtown Jimmie Hale Mission
#
#                                                website  \
# 0    https://reprieveforwomen.com/?utm_source=GMB&u...
# 1    https://bradfordhealth.com/?utm_source=GMB&utm...
# 2                      http://www.raphaministries.net/
# 3    https://experiencethereprieve.com/?utm_source=...
# ...
